# %% [markdown]
# # Tutorial 01: Basic Material Search
#
# Welcome to the first SHALOM tutorial. This notebook demonstrates how to run a basic end-to-end material discovery pipeline using the Design Layer modules.

# %%
from shalom.core.llm_provider import LLMProvider
from shalom.agents.design_layer import CoarseSelector, FineSelector
