# %% [markdown]
# # Tutorial 02: Custom Agent Pipeline
#
# This advanced tutorial demonstrates how to construct custom agent pipelines by chaining the `CoarseSelector`, `FineSelector`, and extending the Simulation Layer `GeometryGenerator`.

# %%
from shalom.core.llm_provider import LLMProvider
from shalom.agents.simulation_layer import GeometryGenerator
